# %% [markdown]
# # Clase 12
# Temas:
# * Formación lineal de estructuras
#
# # Introducción
# - Nos quedamos con perturbaciones en densidad y velocidad
# - Las perturbaciones en materia oscura sólo están acoplados por gravedad, no se ven afectadas por la radiación pero si la afectan.
# - El objetivo es obtener el *espectro de pontencias lineal*
# - Resolveremos su evolución para cada modo de fourier (k) y con el espectro de potencias inicial obtendremos el espectro de potencias en función del redshift.

# %% [markdown]
# # Crecimiento lineal de estructura.
# - La estructura en el universo se forma por inestabilidad gravitacional a partir de pequeñas fluctuaciones generadas por inflación.
# - dos efectos se contraponen: El universo en expansión (lenta si tenemos un un dominio de radiación, crece cuando está dominado por materia y se alentiza cuando domina la aenergía oscura) y la presión de bariones y fotones (la presión aumenta proporcional a la densidad y el gas se mueve a lugares de menor presión = en epocas tempranas las sobredensidades de bariones crecen mas lento que las de CDM)
#
# ![image.png](attachment:image.png)
#
# Se ve que cuando el modo entra al horizonte las perturbaciones de la metrica decrecen y los de mayor escala entran después. Esto está pasando al mismo tiempo que el universo pasa a ser dominado por materia (en lugar de radiación) y son relativamente constantes (todos los modos evolucionan de igual manera) hasta que empieza a dominar la DM.
#
# Para describir esta evolución haremos una separación de variables en la perturbación de la métrica:
# $\Phi =\frac35 \mathcal{R} \times T(k) \times \frac{D_+(a)}{a}$
#
# ![image-2.png](attachment:image-2.png)
#
# Este es un gráfico que vamos a tener que reproducir
#
# despues de $a_{eq}$ vamos a pensar a la materia barionica y oscura yendo juntas, como una única sobredensidad de materia $\delta_m$
#
# $\delta_m (\vec{k},a) = \frac25 \frac{k^2}{\omega_m H_0^2}\mathcal{R}(\vec{k})T(\vec{k})D_+(a)$
#
# a partir de esto obtendremos el espectro lineal de la materia $P_L(\vec{k},a)$
#
# ![image.png](attachment:image.png)
#
# Esto lo podremos calcular con CLASS
#
# Para k pequeño tengo comportamientos parecidos entre los z, luego del turnover (máximo), se ven unas oscilaciones que son evidencia de las BAO (Barion Acoustic Oscillations). Lso picos en la función de correlación entre dos puntos.
#
# El turnover es en la escala que est+á entrando a l horizonte justo cuando se está producinedo equaality, $k_{eq}$. Esta, por supuesto, depende de $\Omega_m$ y $\Omega_\gamma$

# %% [markdown]
# # $K_e(\Omega_m)$
# ![image.png](attachment:image.png)
#
# # $f(a)=\frac{d \ln(D_+(a))}{d \ln(a)}$
#
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# # Efecto de bariones
# + Supresión a escalas pequeñas. Si hay neutrinos masivos veremos una supresión en el espectro de frecuencias puesto que disminuye la T(k).
# + BAOs. Aparecen en la función de transferencia y luego en el espectro de por
# ![image.png](attachment:image.png)
